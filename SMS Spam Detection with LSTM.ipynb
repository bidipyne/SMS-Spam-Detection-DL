# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('SMSSpamCollection', sep='\t', names=['label', 'message'])

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['label'] = pd.get_dummies(df['label'], drop_first=True)

# %%
df.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
data = df['message']

# %%
#Cleaning Data

import nltk
import re
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

# %%
corpus = []
ps = PorterStemmer()

for i in range(len(data)):
    msg = re.sub('[^A-Za-z]', ' ', data[i])
    msg = msg.lower()
    msg = msg.split()
    msg = [ps.stem(word) for word in msg if word not in stopwords.words('english')]
    msg = ' '.join(msg)
    corpus.append(msg)

# %%
len(corpus)
# Out:
# 5572

# %%
corpus[0]
# Out:
# 'go jurong point crazi avail bugi n great world la e buffet cine got amor wat'

# %%
vocab_size = 10000

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
one_hot_rep = [one_hot(word, vocab_size) for word in corpus]
print(one_hot_rep)
# Out:
# [[4305, 2787, 885, 2267, 1517, 1379, 3714, 3744, 7401, 1067, 6565, 1877, 2215, 5354, 2496, 2611], [3724, 2569, 299, 3760, 1299, 4138], [9221, 4179, 7000, 3985, 8388, 3866, 7354, 6092, 8866, 9969, 6081, 5190, 3866, 6760, 4179, 9503, 9564, 6441, 2102, 7404, 4857], [1299, 752, 7364, 8833, 7276, 1299, 7404, 6741, 7364], [5216, 9242, 8195, 4903, 2780, 7547, 4258], [1841, 3267, 2982, 3940, 7162, 6776, 7090, 868, 2028, 2104, 3724, 8313, 9564, 6235, 4735, 9801], [5675, 6283, 7090, 9744, 1522, 7090, 5265, 1635], [4772, 4243, 3726, 3726, 8121, 2385, 4104, 7141, 2396, 3995, 2220, 1731, 4829, 5792, 3995], [7725, 1658, 9648, 9062, 3098, 2690, 233, 605, 9003, 8699, 9003, 4929, 6237, 5929, 5392], [4027, 6499, 1299, 2964, 4156, 7005, 4724, 5449, 4027, 8699, 9221, 8699, 4027, 7005, 6661, 9221], [8022, 6512, 6395, 9543, 3208, 4537, 9073, 8430, 2776, 9962, 4779, 2670], [3539, 8384, 8388, 34, 5380, 6441, 3552, 4735, 3197, 7532, 6670, 6670, 6987, 4857, 3970, 3346, 1347], [2553, 3940, 9221, 8161, 233, 1059, 6441, 7162, 9003, 7404, 5007, 3536, 2586, 8576, 5659, 2673, 5161], [6492, 8624, 7162, 8240, 7404, 533, 6114, 214, 4029, 5202, 7823, 533, 3457, 7578, 5738], [8310, 8243], [2841, 7386, 9583, 1913, 1340, 8633, 1535, 6441, 9586, 1913, 3782, 1340, 2841, 2789, 3714, 3693], [1884, 2776, 7392], [3393, 1299, 4277, 3471, 190, 5090, 3047, 9872, 2774, 3047, 3554], [2648, 1252, 1299, 9880, 1252, 1407, 8939], [9765, 3047, 1091, 474, 808, 1313, 4360, 615, 6441, 9927, 876, 4360, 2420, 9765, 1357, 1857, 4862, 6441, 1382, 3608, 1663], [9364, 3471, 190], [4305, 1357, 6499, 8126, 8126, 299], [2938, 1546, 2569, 692, 3460, 7929], [7046, 3745, 3517, 4305, 1518, 4340, 584, 2929, 4340, 1299, 3745, 9927, 3517, 6741], [3206, 1280, 1252, 3666, 3234], [2261, 2039, 8846, 469, 1273, 4505, 1676, 6800, 1448, 5792, 7253, 1466, 7491, 7421, 2218], [2218, 3182, 5555], [3072, 250, 3010, 3674, 2774, 3536, 2039, 9888, 8255, 419, 9880, 6054], [6776, 1521, 4505, 7842, 6229, 7253, 2959], [3913, 5905, 1388, 4277, 9880, 7090, 2218], [4638, 2028, 1462, 4966, 7659, 134, 9543, 2780, 9993], [5490, 5354, 3047, 4752, 3714, 5841, 8682, 7090, 2172, 2695, 5354, 1773, 4974, 4305, 7239, 5497], [2776, 1102, 5197], [9248, 9297, 2655, 5546, 6170], [8240, 9581, 5138, 5994, 4027, 6422, 6499, 2356, 5554, 3970, 5090, 3970, 6422], [8854, 3724, 4305, 6512, 8401, 5738, 3906, 4391, 4305, 6072, 5134, 6081, 2988], [7845, 6229, 7253, 5672, 9585], [5767, 3468, 8939, 7842], [5197, 4340, 1299, 4905], [2652, 5620, 4305, 5190, 5767, 4905, 5197, 8140, 1357, 4143, 5197], [157, 4305, 7848, 6810, 9543, 4966, 3744, 9878, 2945], [560, 1102, 9543, 8977, 5956, 6054, 4530, 9508, 7261, 6768, 2150], [1695, 8955, 3906, 1357, 8699, 3970, 7840, 9221, 6284, 4027, 9221, 2558, 2356, 8699, 3926, 5201], [5767], [3744, 9331, 7090, 5802, 5316, 8539, 2597, 8774, 1487], [8699, 9586, 808, 8699], [1448, 8485, 8939, 7120, 7074], [265, 4779, 5197, 4305], [5490, 9331, 1523, 1585, 5331, 7981, 7547, 5539], [1299, 7253, 4071, 5675, 9543, 4305, 1233, 1200, 1102, 6800, 2621, 3926, 1233, 2621, 3926], [9242, 1546, 5738, 1570, 2360], [1613, 9907, 7088, 7090, 2597, 8774, 871, 8023, 6559, 4258, 1448, 5385, 7976, 3792, 1613, 2597, 8774], [2776, 9709, 134, 2793, 8833, 5201, 8662, 2284, 6650, 8430], [990, 7493, 9467, 887, 7995, 8630, 7090, 4544, 2571, 1585, 3182, 9356, 1636, 4276, 6433, 3655, 6433, 2608, 6433, 2959, 887], [7840, 2201, 7649, 6848, 8733, 1158, 3979, 6593, 456, 4032, 1574, 1640, 6049, 7288, 3022, 3970, 3022, 7649], [7253, 8077, 352, 7982, 731, 2597, 674, 8774], [475, 7746, 8076, 4068, 6812, 8699, 7404, 8085, 3047, 4498, 8394, 6412, 9221, 2116, 622, 7554, 474, 808], [6433, 8699, 3983, 3666], [1102, 4843], [5090, 7762, 4875, 5452, 4925], [8022, 3620, 372, 1252, 6512, 5675, 2641, 3171, 5515], [8126, 8126, 8126, 588, 299, 3295, 9869, 3288], [6936, 8741, 5775], [6433, 5672, 4368, 9885, 3724, 104], [3724, 2569, 3593, 8741, 3760, 692, 1014, 6254, 6741, 1477, 3753, 3071, 3047, 5120, 1477, 3071, 8401, 6523], [1658, 9062, 2356, 2200, 5282, 9968, 8985, 287 ...

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sent_len = 20
embedded = pad_sequences(one_hot_rep,maxlen=sent_len)
print(embedded)
# Out:
# [[   0    0    0 ... 5354 2496 2611]
#  [   0    0    0 ... 3760 1299 4138]
#  [4179 7000 3985 ... 2102 7404 4857]
#  ...
#  [   0    0    0 ...  314 3095 7887]
#  [   0    0    0 ... 1130 9993 9221]
#  [   0    0    0 ... 1260  596  190]]

# %%
X = np.array(embedded)
y = df['label'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (4457, 20)
# (4457,)

# %%
np.unique(y_train)
# Out:
# array([0, 1], dtype=uint8)

# %%
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

# %%
from tensorflow.keras.models import Sequential

# %%
feature_vector = 20

model = Sequential()
model.add(Embedding(vocab_size, feature_vector, input_length=sent_len))
#model.add(Dropout(0.5))
model.add(LSTM(100))
#model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 20)            200000
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               48400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 248,501
# Trainable params: 248,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train, batch_size=50, epochs=10, validation_data=(X_test,y_test))
# Out:
# Train on 4457 samples, validate on 1115 samples
# Epoch 1/10
# 4457/4457 [==============================] - 18s 4ms/sample - loss: 0.2927 - accuracy: 0.8984 - val_loss: 0.0988 - val_accuracy: 0.9776
# Epoch 2/10
# 4457/4457 [==============================] - 4s 902us/sample - loss: 0.0667 - accuracy: 0.9827 - val_loss: 0.0514 - val_accuracy: 0.9839
# Epoch 3/10
# 4457/4457 [==============================] - 4s 914us/sample - loss: 0.0317 - accuracy: 0.9915 - val_loss: 0.0409 - val_accuracy: 0.9839
# Epoch 4/10
# 4457/4457 [==============================] - 3s 741us/sample - loss: 0.0203 - accuracy: 0.9924 - val_loss: 0.0563 - val_accuracy: 0.9830
# Epoch 5/10
# 4457/4457 [==============================] - 3s 707us/sample - loss: 0.0142 - accuracy: 0.9969 - val_loss: 0.0446 - val_accuracy: 0.9865
# Epoch 6/10
# 4457/4457 [==============================] - 3s 707us/sample - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.0424 - val_accuracy: 0.9892
# Epoch 7/10
# 4457/4457 [==============================] - 3s 738us/sample - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.0436 - val_accuracy: 0.9883
# Epoch 8/10
# 4457/4457 [==============================] - 4s 855us/sample - loss: 0.0046 - accuracy: 0.9980 - val_loss: 0.0484 - val_accuracy: 0.9883
# Epoch 9/10
# 4457/4457 [==============================] - 3s 714us/sample - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0443 - val_accuracy: 0.9892
# Epoch 10/10
# 4457/4457 [==============================] - 4s 902us/sample - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0518 - val_accuracy: 0.9865

# %%
y_pred = model.predict_classes(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
print(confusion_matrix(y_test,y_pred))
print()
print(accuracy_score(y_test,y_pred))
print()
print(classification_report(y_test,y_pred, zero_division=1))
# Out:
# [[960   5]
#  [ 10 140]]
#
# 0.9865470852017937
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       965
#            1       0.97      0.93      0.95       150
#
#     accuracy                           0.99      1115
#    macro avg       0.98      0.96      0.97      1115
# weighted avg       0.99      0.99      0.99      1115

# %%
model.save('nlp_model.h5')
